# %%
import numpy as np
import pandas as pd
import os 
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt 
from sklearn.kernel_ridge import KernelRidge
import seaborn as sns
base_path = os.getcwd()

# %%
train_data = pd.read_csv("Train_Data.csv")
fingerprint_0 = pd.read_csv("Fingerprint_0.csv")
fingerprint_1 = pd.read_csv("Fingerprint_1.csv")
fingerprint_2 = pd.read_csv("Fingerprint_2.csv")
fingerprint_3 = pd.read_csv("Fingerprint_3.csv")

# %%
def model_data(data):
    train_data = pd.read_csv("Train_Data.csv")
    train_size = 2000/len(train_data)
    columns_training = ['U0','zpve','alpha','CV','gap']
    for column in columns_training:
        scaler_y = MinMaxScaler()
        data_y = scaler_y.fit_transform(np.array(train_data[column]).reshape(-1, 1))
        train_X, test_X, train_Y, test_Y = train_test_split(data,data_y,train_size=test_size)
        kr = GridSearchCV(KernelRidge(kernel='rbf', gamma=0.1),
                      param_grid={"alpha": [1e0, 0.1, 1e-2, 1e-3],
                                  "gamma": np.logspace(-2, 2, 5)})
        t0 = time.time()
        kr.fit(train_X, train_Y)
        kr_fit = time.time() - t0
        print("KRR model fitting + hyperparameter tuning for {} done in =  {} s".format(column,kr_fit))
        print("Train Score -{}".format(kr.score(train_X,train_Y)))
        print("Test Score - {}".format(kr.score(test_X,test_Y)))
        plt.scatter(scaler_y.inverse_transform(test_Y),scaler_y.inverse_transform(kr.predict(test_X)))
        plt.scatter(scaler_y.inverse_transform(train_Y),scaler_y.inverse_transform(kr.predict(train_X)))
        plt.axis('square')
        plt.show()

# %%
model_data(fingerprint_0)
# Out:
# KRR model fitting + hyperparameter tuning for U0 done in =  27.4783296585083 s
# Train Score -0.8089997288602402
# Test Score - 0.6669768991265661
# KRR model fitting + hyperparameter tuning for zpve done in =  27.190848350524902 s
# Train Score -0.9077800471316715
# Test Score - 0.8776023969381436
# KRR model fitting + hyperparameter tuning for alpha done in =  29.01906728744507 s
# Train Score -0.7807533965287873
# Test Score - 0.4877637072554887
# KRR model fitting + hyperparameter tuning for CV done in =  28.943732976913452 s
# Train Score -0.5690801312657722
# Test Score - 0.4613454082585492
# KRR model fitting + hyperparameter tuning for gap done in =  28.871654272079468 s
# Train Score -0.28884763055221274
# Test Score - 0.3147346969645075

# %%
model_data(fingerprint_1)
# Out:
# KRR model fitting + hyperparameter tuning for U0 done in =  30.769275426864624 s
# Train Score -0.9399477262738843
# Test Score - 0.7472994038846681
# KRR model fitting + hyperparameter tuning for zpve done in =  27.196136951446533 s
# Train Score -0.9539205910985259
# Test Score - 0.9094724231809154
# KRR model fitting + hyperparameter tuning for alpha done in =  26.999932050704956 s
# Train Score -0.6244131282640561
# Test Score - 0.6148769859716586
# KRR model fitting + hyperparameter tuning for CV done in =  27.706119537353516 s
# Train Score -0.8293590472735136
# Test Score - 0.5331425093236808
# KRR model fitting + hyperparameter tuning for gap done in =  30.525625228881836 s
# Train Score -0.8484506524449993
# Test Score - 0.8480568600067829

# %%
model_data(fingerprint_2)
# Out:
# KRR model fitting + hyperparameter tuning for U0 done in =  27.709507703781128 s
# Train Score -0.6472847335348825
# Test Score - 0.6518448576171493
# KRR model fitting + hyperparameter tuning for zpve done in =  30.037176847457886 s
# Train Score -0.8999181820266572
# Test Score - 0.879614387106288
# KRR model fitting + hyperparameter tuning for alpha done in =  27.348292589187622 s
# Train Score -0.6640668059603683
# Test Score - 0.6429089001225523
# KRR model fitting + hyperparameter tuning for CV done in =  34.62290072441101 s
# Train Score -0.6602247237373648
# Test Score - 0.5953125750499169
# KRR model fitting + hyperparameter tuning for gap done in =  31.72325110435486 s
# Train Score -0.9349477566541784
# Test Score - 0.9251695959408289

# %%
model_data(fingerprint_3)
# Out:
# KRR model fitting + hyperparameter tuning for U0 done in =  28.095397233963013 s
# Train Score -0.7270568220051221
# Test Score - 0.6451914824412714
# KRR model fitting + hyperparameter tuning for zpve done in =  30.67574453353882 s
# Train Score -0.9223399356640815
# Test Score - 0.8785520870468347
# KRR model fitting + hyperparameter tuning for alpha done in =  31.2423357963562 s
# Train Score -0.6997206767380639
# Test Score - 0.6621326253820167
# KRR model fitting + hyperparameter tuning for CV done in =  31.02769112586975 s
# Train Score -0.7912197458335971
# Test Score - 0.6650621255204733
# KRR model fitting + hyperparameter tuning for gap done in =  29.85840630531311 s
# Train Score -0.9494349253069548
# Test Score - 0.9244015387969738

# %%
def model_results():
    train_data = pd.read_csv("Train_Data.csv")
    train_size = 2000/len(train_data)
    fingerprint_0 = pd.read_csv("Fingerprint_0.csv")
    fingerprint_1 = pd.read_csv("Fingerprint_1.csv")
    fingerprint_2 = pd.read_csv("Fingerprint_2.csv")
    fingerprint_3 = pd.read_csv("Fingerprint_3.csv")
    columns_training = ['U0','zpve','alpha','CV','gap']
    total_data = [fingerprint_0,fingerprint_1,fingerprint_2,fingerprint_3]
    fig,axs = plt.subplots(len(total_data),len(columns_training))
    fig = plt.figure(figsize=(30, 30))
    for i,data in zip(range(len(total_data)),total_data):
        for j,column in zip(range(len(columns_training)),columns_training):
            scaler_y = MinMaxScaler()
            data_y = scaler_y.fit_transform(np.array(train_data[column]).reshape(-1, 1))
            train_X, test_X, train_Y, test_Y = train_test_split(data,data_y,train_size=test_size)
            kr = GridSearchCV(KernelRidge(kernel='rbf', gamma=0.1),
                          param_grid={"alpha": [1e0, 0.1, 1e-2, 1e-3],
                                      "gamma": np.logspace(-2, 2, 5)})
            t0 = time.time()
            kr.fit(train_X, train_Y)
            kr_fit = time.time() - t0
            print("KRR model fitting + hyperparameter tuning for {} done in =  {} s".format(column,kr_fit))
            print("Train Score -{}".format(kr.score(train_X,train_Y)))
            print("Test Score - {}".format(kr.score(test_X,test_Y)))
            axs[i,j].scatter(scaler_y.inverse_transform(test_Y),scaler_y.inverse_transform(kr.predict(test_X)))
            axs[i,j].scatter(scaler_y.inverse_transform(train_Y),scaler_y.inverse_transform(kr.predict(train_X)))
            axs[i,j].axis('square')
    plt.show()

# %%
model_results()
# Out:
# KRR model fitting + hyperparameter tuning for U0 done in =  27.1098051071167 s
# Train Score -0.7898650026225212
# Test Score - 0.6579968699377703
# KRR model fitting + hyperparameter tuning for zpve done in =  27.136898517608643 s
# Train Score -0.9354554119797034
# Test Score - 0.7935558907982097
# KRR model fitting + hyperparameter tuning for alpha done in =  27.510486841201782 s
# Train Score -0.7206337360507585
# Test Score - 0.5295665667156049
# KRR model fitting + hyperparameter tuning for CV done in =  26.976516723632812 s
# Train Score -0.5139957672747226
# Test Score - 0.3603826165836965
# KRR model fitting + hyperparameter tuning for gap done in =  26.87902283668518 s
# Train Score -0.3166073240538835
# Test Score - 0.3141562747269887
# KRR model fitting + hyperparameter tuning for U0 done in =  27.07820463180542 s
# Train Score -0.891128536702841
# Test Score - 0.6767379220973522
# KRR model fitting + hyperparameter tuning for zpve done in =  26.775245666503906 s
# Train Score -0.9689442411925128
# Test Score - 0.8863558609520551
# KRR model fitting + hyperparameter tuning for alpha done in =  26.85084843635559 s
# Train Score -0.7042409397794607
# Test Score - 0.6110021986190668
# KRR model fitting + hyperparameter tuning for CV done in =  27.55191946029663 s
# Train Score -0.6583393752253484
# Test Score - 0.5691428061654539
# KRR model fitting + hyperparameter tuning for gap done in =  34.26318311691284 s
# Train Score -0.8563200376422784
# Test Score - 0.847504480086599
# KRR model fitting + hyperparameter tuning for U0 done in =  28.042733907699585 s
# Train Score -0.7165232546066909
# Test Score - 0.6504812223107601
# KRR model fitting + hyperparameter tuning for zpve done in =  27.117220401763916 s
# Train Score -0.8953631306958754
# Test Score - 0.8782737797522344
# KRR model fitting + hyperparameter tuning for alpha done in =  37.00575590133667 s
# Train Score -0.67150903273494
# Test Score - 0.6418689704065415
# KRR model fitting + hyperparameter tuning for CV done in =  35.66987061500549 s
# Train Score -0.6238390941722012
# Test Score - 0.5968485902936325
# KRR model fitting + hyperparameter tuning for gap done in =  32.89990210533142 s
# Train Score -0.9322614503432999
# Test Score - 0.9244705816259773
# KRR model fitting + hyperparameter tuning for U0 done in =  37.52809190750122 s
# Train Score -0.7257573591328427
# Test Score - 0.6447547405465366
# KRR model fitting + hyperparameter tuning for zpve done in =  33.36195158958435 s
# Train Score -0.9019548881363021
# Test Score - 0.876128975827795
# KRR model fitting + hyperparameter tuning for alpha done in =  33.552504777908325 s
# Train Score -0.7055684344237819
# Test Score - 0.6645894375412074
# KRR model fitting + hyperparameter tuning for CV done in =  27.685163021087646 s
# Train Score -0.6969472567896173
# Test Score - 0.6784347439988223
# KRR model fitting + hyperparameter tuning for gap done in =  31.40605092048645 s
# Train Score -0.9417420266128864
# Test Score - 0.928541463861955

# %%
model_results()
# Out:
# KRR model fitting + hyperparameter tuning for U0 done in =  27.896432638168335 s
# Train Score -0.6563702220241648
# Test Score - 0.636289894824978
# KRR model fitting + hyperparameter tuning for zpve done in =  28.035647869110107 s
# Train Score -0.9091175715222571
# Test Score - 0.8955326068171288
# KRR model fitting + hyperparameter tuning for alpha done in =  27.865122079849243 s
# Train Score -0.5853659164803786
# Test Score - 0.5781161576836802
# KRR model fitting + hyperparameter tuning for CV done in =  26.885194301605225 s
# Train Score -0.3788942193924809
# Test Score - 0.3852287959966889
# KRR model fitting + hyperparameter tuning for gap done in =  37.42186117172241 s
# Train Score -0.3457294275417211
# Test Score - 0.31142903547771705
# KRR model fitting + hyperparameter tuning for U0 done in =  55.27241253852844 s
# Train Score -0.906471666761023
# Test Score - 0.6499781278570869
# KRR model fitting + hyperparameter tuning for zpve done in =  49.68085074424744 s
# Train Score -0.9425533061133206
# Test Score - 0.893019010686858
# KRR model fitting + hyperparameter tuning for alpha done in =  50.51049780845642 s
# Train Score -0.636604192239886
# Test Score - 0.6058024092525576
# KRR model fitting + hyperparameter tuning for CV done in =  47.93706703186035 s
# Train Score -0.8277589773440011
# Test Score - 0.5287370000310158
# KRR model fitting + hyperparameter tuning for gap done in =  44.1175901889801 s
# Train Score -0.8706910111833618
# Test Score - 0.8508970382282335
# KRR model fitting + hyperparameter tuning for U0 done in =  50.38560891151428 s
# Train Score -0.6453864125623316
# Test Score - 0.6446081414989067
# KRR model fitting + hyperparameter tuning for zpve done in =  44.91990613937378 s
# Train Score -0.8983772568445482
# Test Score - 0.8763956057800395
# KRR model fitting + hyperparameter tuning for alpha done in =  42.64276695251465 s
# Train Score -0.7521989431351678
# Test Score - 0.6160960648755689
# KRR model fitting + hyperparameter tuning for CV done in =  49.232959032058716 s
# Train Score -0.6267973385880594
# Test Score - 0.5999313027058981
# KRR model fitting + hyperparameter tuning for gap done in =  46.77520275115967 s
# Train Score -0.9212777863531326
# Test Score - 0.9204191616705405
# KRR model fitting + hyperparameter tuning for U0 done in =  50.44396615028381 s
# Train Score -0.6881399879789301
# Test Score - 0.64149171957095
# KRR model fitting + hyperparameter tuning for zpve done in =  43.76853084564209 s
# Train Score -0.9002804480645598
# Test Score - 0.8755859208395508
# KRR model fitting + hyperparameter tuning for alpha done in =  45.187355279922485 s
# Train Score -0.7175810014939779
# Test Score - 0.6596302099174978
# KRR model fitting + hyperparameter tuning for CV done in =  45.90467095375061 s
# Train Score -0.7250270731439477
# Test Score - 0.6693913054388073
# KRR model fitting + hyperparameter tuning for gap done in =  44.972923278808594 s
# Train Score -0.9501011791428197
# Test Score - 0.9280574443715278
